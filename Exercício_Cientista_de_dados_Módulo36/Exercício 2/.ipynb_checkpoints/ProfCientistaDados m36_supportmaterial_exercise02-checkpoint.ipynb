# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tarefa II

# %% [markdown]
# Ainda sobre a base da NFP vista na tarefa passada:
#
# |Campo|Descrição|
# |:-|:-|
# |CNPJ emit.| CNPJ do emitente da nota|
# |Emitente| Nome fantasia do emitente da nota|
# |No.| Número da nota fiscal|
# |Data Emissão| Data de emissão da nota fiscal|
# |Valor NF| Valor da nota fiscal|
# |Data Registro| Data de registro no sistema da NFP|
# |Créditos| Valor dos créditos (doação)|
# |Situação do Crédito| Se o crédito já foi pago, está sendo processado etc.|
# |Ano| Ano da emissão da nota|
# |Semestre| Semestre da emissão da nota|
# |Retorno| Valor do crédito dividido pelo valor da nota|
# |flag_credito| Indicadora se a nota possui crédito positivo|
# |categoria| Categorização da nota |
#
# **OBJETIVO:** Algumas notas não dão retorno, o que pode ocorrer por diversos motivos, um deles seria a ocorrência de produtos não incentivados como cigarros e bebidas alcólicas. O nosso objetivo é tentar prever que tipo de nota tem maior ou menor propensão a fornecer créditos.
#
# **Observação**: Esta é uma base real, havendo características de acordo. Pode haver uma variabilidade difícil de explicar, em parte por causa de uma freqüência de notas inconstante no tempo (por diversos motivos), em parte por haverem informações importantes, protegidas pela LGPD, não constantes na base, que pode interferir no crédito gerado, o que vai ocasionar uma variabilidade difícil de se explicar. *Welcome to the jungle*, A vida real é assim :)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_theme()

# %reload_ext watermark
# %watermark -iv -v

import warnings

warnings.filterwarnings("ignore")
# Out:
# Python implementation: CPython
# Python version       : 3.11.5
# IPython version      : 8.15.0
#
# matplotlib: 3.8.2
# numpy     : 1.26.2
# pandas    : 2.1.4
# seaborn   : 0.13.1

# %%
def analise(data, y):
    analise = pd.DataFrame({'dtype': data.dtypes,
                            'contagem': data.count(),
                            'missing': data.isna().sum(),
                            'nunique': data.nunique(),
                            'papel': 'covariavel'})
    analise.loc[analise.index == y, 'papel'] = 'resposta'
    return analise

def IV(variavel, resposta):
    tab = pd.crosstab(variavel, resposta, margins=True, margins_name='total')

    rótulo_nao_evento = tab.columns[0]
    rótulo_evento = tab.columns[1]

    tab['pct_evento'] = tab[rótulo_evento]/tab.loc['total',rótulo_evento]
    tab['pct_nao_evento'] = tab[rótulo_nao_evento]/tab.loc['total',rótulo_nao_evento]
    tab['woe'] = np.log(tab.pct_evento/tab.pct_nao_evento)
    tab['iv_parcial'] = (tab.pct_evento - tab.pct_nao_evento)*tab.woe
    return tab

# %%
df = pd.read_pickle('./Dados/base_nfp.pkl')
df.head()
# Out:
#            CNPJ emit.                                           Emitente  \
# 0  03.476.811/0741-98                      DIA BRASIL SOCIEDADE LIMITADA
# 1  43.101.310/0001-05                         AUTO POSTO ZANWAL LTDA EPP
# 2  23.750.257/0001-66  OFICINA DO TRIGO PASTIFICIO PANIFICADORA BAR E RE
# 3  23.750.257/0001-66  OFICINA DO TRIGO PASTIFICIO PANIFICADORA BAR E RE
# 4  23.750.257/0001-66  OFICINA DO TRIGO PASTIFICIO PANIFICADORA BAR E RE
#
#     No. Data Emissão  Valor NF Data Registro  Créditos Situação do Crédito  \
# 0   537   2017-06-30     24.68    2017-06-30      0.00            Liberado
# 1  2894   2017-06-30     50.00    2017-06-30      0.00            Liberado
# 2   699   2017-06-30     27.00    2017-06-30      0.44            Liberado
# 3   698   2017-06-30    111.50    2017-06-30      1.81            Liberado
# 4   694   2017-06-30    125.00    2017-06-30      2.03            Liberado
#
#     Ano  Semestre   Retorno  flag_credito     categoria
# 0  2017         1  0.000000             0       Mercado
# 1  2017         1  0.000000             0    Auto posto
# 2  2017         1  0.016296             1  Restaurantes
# 3  2017         1  0.016233             1  Restaurantes
# 4  2017         1  0.016240             1  Restaurantes

# %%
df['Retorno'].fillna(0, inplace=True)
df = df.loc[df['Retorno'] < 800]
df.reset_index(inplace=True, drop=True)

analise(data=df, y='flag_credito')
# Out:
#                               dtype  contagem  missing  nunique       papel
# CNPJ emit.                   object    187645        0    19606  covariavel
# Emitente                     object    187645        0    15575  covariavel
# No.                           int64    187645        0   124400  covariavel
# Data Emissão         datetime64[ns]    187645        0     1815  covariavel
# Valor NF                    float64    187645        0    33658  covariavel
# Data Registro        datetime64[ns]    187645        0     1817  covariavel
# Créditos                    float64    187645        0     9717  covariavel
# Situação do Crédito        category    187645        0        3  covariavel
# Ano                           int64    187645        0        5  covariavel
# Semestre                      int64    187645        0        2  covariavel
# Retorno                     float64    187645        0    60201  covariavel
# flag_credito                  int64    187645        0        2    resposta
# categoria                    object    187645        0        9  covariavel

# %% [markdown]
# ## Criando variáveis
#
# **Variáveis temporais**: É possível que haja alguma regra de liberação de créditos de acordo com o dia do mês, o dia da semana, fim de semana (sim ou não), ou até alterações temporais da regra. Vamos criar as seguintes variáveis para testar estas hipóteses:
#
# - Dia da semana
# - Dummy para fim de semana
# - Dia do mês
# - Mês (já na base)
# - Trimestre
# - Ano (já na base)
#
# **Valor da nota**: Vamos criar também algumas variáveis para resumir o valor da nota, e posteriormente criar uma intuição sobre categorizações de variáveis contínuas.
#
# - Crie categorizações da variável ```Valor NF```, por quantís, em 5, 10, 20 e 50 categorias.

# %%
# Variáveis Temporais
df['Dia_da_Semana'] = df['Data Emissão'].dt.weekday
df['Fim_de_Semana'] = df['Dia_da_Semana'].isin([5,6]).astype('int')
df['Dia_do_mes']    = df['Data Emissão'].dt.day
df['Mes']           = df['Data Emissão'].dt.month
df['Trimestre']     = df['Data Emissão'].dt.to_period('Q')

df[['Dia_da_Semana',
    'Fim_de_Semana',
    'Dia_do_mes',
    'Mes',
    'Trimestre',
    'Ano']].nunique().to_frame('Quantidade')
# Out:
#                Quantidade
# Dia_da_Semana           7
# Fim_de_Semana           2
# Dia_do_mes             31
# Mes                    12
# Trimestre              20
# Ano                     5

# %%
# Valor da Nota

df['Valor_NF_Cat_5'] = pd.qcut(df['Valor NF'], q=5, labels=False)
df['Valor_NF_Cat_10'] = pd.qcut(df['Valor NF'], q=10, labels=False)
df['Valor_NF_Cat_20'] = pd.qcut(df['Valor NF'], q=20, labels=False)
df['Valor_NF_Cat_50'] = pd.qcut(df['Valor NF'], q=50, labels=False)

df[['Valor_NF_Cat_5',
    'Valor_NF_Cat_10',
    'Valor_NF_Cat_20',
    'Valor_NF_Cat_50']].nunique().to_frame('Quantidade')
# Out:
#                  Quantidade
# Valor_NF_Cat_5            5
# Valor_NF_Cat_10          10
# Valor_NF_Cat_20          20
# Valor_NF_Cat_50          50

# %% [markdown]
# ## Calcule o IV de todas essas variáveis
#
# Sugestão: Construa um metadados e tente utilizar uma função como a que foi utilizada durante a aula. Você vai conseguir fazer esse cálculo para as variáveis uma a uma, mas em casos reais em que vamos mais além na criação de variáveis, podemos ter centenas, ou até milhares de variáveis, esses cálculos *precisam* ser automáticos nesses casos.

# %%
df_tratado = df.drop(columns=['CNPJ emit.', 'No.', 'Emitente', 'Data Emissão', 'Data Registro', 'Situação do Crédito'])
metadados = analise(data=df_tratado,y='flag_credito')
metadados
# Out:
#                          dtype  contagem  missing  nunique       papel
# Valor NF               float64    187645        0    33658  covariavel
# Créditos               float64    187645        0     9717  covariavel
# Ano                      int64    187645        0        5  covariavel
# Semestre                 int64    187645        0        2  covariavel
# Retorno                float64    187645        0    60201  covariavel
# flag_credito             int64    187645        0        2    resposta
# categoria               object    187645        0        9  covariavel
# Dia_da_Semana            int32    187645        0        7  covariavel
# Fim_de_Semana            int32    187645        0        2  covariavel
# Dia_do_mes               int32    187645        0       31  covariavel
# Mes                      int32    187645        0       12  covariavel
# Trimestre        period[Q-DEC]    187645        0       20  covariavel
# Valor_NF_Cat_5           int64    187645        0        5  covariavel
# Valor_NF_Cat_10          int64    187645        0       10  covariavel
# Valor_NF_Cat_20          int64    187645        0       20  covariavel
# Valor_NF_Cat_50          int64    187645        0       50  covariavel

# %%
for var in metadados[metadados.papel=='covariavel'].index:
    if  (metadados.loc[var, 'nunique']>50):
        metadados.loc[var, 'IV'] = IV(pd.qcut(df_tratado[var],5,duplicates='drop'), df_tratado.flag_credito)['iv_parcial'].sum()
    else: 
        metadados.loc[var, 'IV'] = IV(df_tratado[var], df_tratado.flag_credito)['iv_parcial'].sum()
    
metadados.sort_values(by='IV', ascending=False, inplace=True)
metadados
# Out:
#                          dtype  contagem  missing  nunique       papel  \
# Créditos               float64    187645        0     9717  covariavel
# Retorno                float64    187645        0    60201  covariavel
# categoria               object    187645        0        9  covariavel
# Valor_NF_Cat_50          int64    187645        0       50  covariavel
# Valor_NF_Cat_20          int64    187645        0       20  covariavel
# Valor_NF_Cat_10          int64    187645        0       10  covariavel
# Trimestre        period[Q-DEC]    187645        0       20  covariavel
# Valor NF               float64    187645        0    33658  covariavel
# Valor_NF_Cat_5           int64    187645        0        5  covariavel
# Dia_do_mes               int32    187645        0       31  covariavel
# Ano                      int64    187645        0        5  covariavel
# Mes                      int32    187645        0       12  covariavel
# Dia_da_Semana            int32    187645        0        7  covariavel
# Fim_de_Semana            int32    187645        0        2  covariavel
# Semestre                 int64    187645        0        2  covariavel
# flag_credito             int64    187645        0        2    resposta
#
#                        IV
# Créditos              inf
# Retorno               inf
# categoria        0.408317
# Valor_NF_Cat_50  0.152360
# Valor_NF_Cat_20  0.124560
# Valor_NF_Cat_10  0.106673
# Trimestre        0.079890
# Valor NF         0.056703
# Valor_NF_Cat_5   0.056703
# Dia_do_mes       0.043720
# Ano              0.041652
# Mes              0.027830
# Dia_da_Semana    0.006886
# Fim_de_Semana    0.004347
# Semestre         0.001259
# flag_credito          NaN

# %% [markdown]
# ## Conclua
#
# - Quais variáveis parecem apresentar maior poder de discriminação segundo o IV?
#
# **Resposta**: 'categoria': 0.408 (Forte)
#
# - Quando categorizamos variáveis contínuas parece haver alguma relação entre o número de categorias e o IV?
#
# **Resposta**: Vemos que quanto maior o número de categorias, melhor é o IV.
#
# | Valor_NF_Cat_50 | Valor_NF_Cat_20 | Valor_NF_Cat_10 | Valor_NF_Cat_5 | Valor NF |
# | --------------- | --------------- | --------------- | -------------- | -------- |
# |      0.152      |      0.125      |      0.107      |      0.057     |   0.057  |
# |     (Médio)     |     (Médio)     |     (Médio)     |     (Fraco)    |  (Fraco) |

# %%
print(f'\033[1;7mInformation Value (IV):\033[0m\n{"-"*36}')

for i, j in zip(metadados.index, metadados.IV):
    if j > 0.5:
        print(f'\033[1m{i}:\033[0m\033[1;91m {j:.3f} (Suspeito de tão alto)\033[0m\n{"-"*36}')
    elif j > 0.3:
        print(f'\033[1m{i}:\033[0m\033[1;94m {j:.3f} (Forte)\033[0m\n{"-"*36}')
    elif j > 0.1:
        print(f'\033[1m{i}:\033[0m\033[1;92m {j:.3f} (Médio)\033[0m\n{"-"*36}')
    elif j > 0.02:
        print(f'\033[1m{i}:\033[0m\033[1;93m {j:.3f} (Fraco)\033[0m\n{"-"*36}')
    else:
        print(f'\033[1m{i}:\033[0m\033[1;91m {j:.3f} (Inútil)\033[0m\n{"-"*36}')
# Out:
# Information Value (IV):
# ------------------------------------
# Créditos: inf (Suspeito de tão alto)
# ------------------------------------
# Retorno: inf (Suspeito de tão alto)
# ------------------------------------
# categoria: 0.408 (Forte)
# ------------------------------------
# Valor_NF_Cat_50: 0.152 (Médio)
# ------------------------------------
# Valor_NF_Cat_20: 0.125 (Médio)
# ------------------------------------
# Valor_NF_Cat_10: 0.107 (Médio)
# ------------------------------------
# Trimestre: 0.080 (Fraco)
# ------------------------------------
# Valor NF: 0.057 (Fraco)
# ------------------------------------
# Valor_NF_Cat_5: 0.057 (Fraco)
# ------------------------------------
# Dia_do_mes: 0.044 (Fraco)
# ------------------------------------
# Ano: 0.042 (Fraco)
# ------------------------------------
# Mes: 0.028 (Fraco)
# ------------------------------------
# Dia_da_Semana: 0.007 (Inútil)
# ------------------------------------
# Fim_de_Semana: 0.004 (Inútil)
# ------------------------------------
# Semestre: 0.001 (Inútil)
# ------------------------------------
# flag_credito: nan (Inútil)
# ------------------------------------

# %% [markdown]
# ## Descritiva simples no tempo
#
# Para compor a análise que virá a seguir, faça uma análise descritiva básica no tempo - utilize trimestre como agregação (ou uma média móvel por trimestre, como preferir) e avalie graficamente:
#
# - A quantidade de notas registradas na base por período
# - A quantidade de notas por categoria e por período
# - A proporção de notas com crédito por categoria por período

# %% [markdown]
# ## A quantidade de notas registradas na base por período

# %%
graf1 = pd.crosstab(df['Trimestre'], df['flag_credito'], margins=True, margins_name='Total')
graf1
# Out:
# flag_credito       0      1   Total
# Trimestre
# 2017Q1          8130   5288   13418
# 2017Q2          6525   4790   11315
# 2017Q3          6928   4234   11162
# 2017Q4          4607   3106    7713
# 2018Q1           701    459    1160
# 2018Q2           883   1023    1906
# 2018Q3          1259   1223    2482
# 2018Q4          1903   2168    4071
# 2019Q1          3047   4149    7196
# 2019Q2          3964   5506    9470
# 2019Q3          9154   6088   15242
# 2019Q4          6269   9286   15555
# 2020Q1          6014   4570   10584
# 2020Q2          6049   3561    9610
# 2020Q3          6289   4427   10716
# 2020Q4          6346   4956   11302
# 2021Q1          5507   4576   10083
# 2021Q2          6118   4670   10788
# 2021Q3          6329   5293   11622
# 2021Q4          6986   5264   12250
# Total         103008  84637  187645

# %%
graf1.drop('Total').plot.bar(figsize=(10,5), edgecolor='black')
plt.ylabel('Quantidade')
plt.title('Quantidade de notas registradas na base por período', fontsize=14)
plt.legend()

# %% [markdown]
# ## A quantidade de notas por categoria e por período

# %%
graf2 = pd.crosstab(df['Trimestre'], df['categoria'], margins=True, margins_name='Total')
graf2
# Out:
# categoria  Alimentos  Auto posto  Construção  Farmácia  Mercado  Restaurantes  \
# Trimestre
# 2017Q1          1285         744        1410       639     1344          7568
# 2017Q2          1744         355         528       498      960          6629
# 2017Q3          1344         844         686       431      769          6355
# 2017Q4           573         546         593       384      835          4221
# 2018Q1            44          55         144        47      386           279
# 2018Q2            96          48         192        59      852           238
# 2018Q3            83          59         192        93      523          1023
# 2018Q4           101          55         301       155     2121           710
# 2019Q1          1075          89        1888       405     1271          1092
# 2019Q2          1738         113        1970       582     1646          1362
# 2019Q3          1001         115        3992       744     2181          4388
# 2019Q4           826         126        4293       714     2249          3705
# 2020Q1           701          88        1999      1218     3404           541
# 2020Q2           562          62        1844      1197     3213           195
# 2020Q3           553          57        1929      1201     3535           226
# 2020Q4           685          62        1939      1269     3649           229
# 2021Q1           581          64        1855      1214     3323           213
# 2021Q2           605          54        1962      1295     3342           231
# 2021Q3           674          79        2150      1368     3558           287
# 2021Q4           689          74        2369      1427     3534           257
# Total          14960        3689       32236     14940    42695         39749
#
# categoria  Varejo  Vestuário  não definido   Total
# Trimestre
# 2017Q1         13         18           397   13418
# 2017Q2         34         44           523   11315
# 2017Q3         18         62           653   11162
# 2017Q4         12         46           503    7713
# 2018Q1         12         14           179    1160
# 2018Q2         26         40           355    1906
# 2018Q3         35        101           373    2482
# 2018Q4         32        199           397    4071
# 2019Q1        102        185          1089    7196
# 2019Q2        133        302          1624    9470
# 2019Q3        183        334          2304   15242
# 2019Q4        238        347          3057   15555
# 2020Q1        389        235          2009   10584
# 2020Q2        472        139          1926    9610
# 2020Q3        615        214          2386   10716
# 2020Q4        772        271          2426   11302
# 2021Q1        560        194          2079   10083
# 2021Q2        794        287          2218   10788
# 2021Q3        725        242          2539   11622
# 2021Q4        739        338          2823   12250
# Total        5904       3612         29860  187645

# %%
graf2.sort_values(by='Total', axis=1, ascending=False, inplace=True)
graf2.drop('Total', axis=1).drop('Total').plot.bar(figsize=(10,5), edgecolor='black', stacked=True)
plt.ylabel('Quantidade')
plt.title('Quantidade de notas por categoria e por período', fontsize=14)
plt.legend(bbox_to_anchor=(1, 1))

# %% [markdown]
# ## A proporção de notas com crédito por categoria por período

# %%
df_credito = df.loc[df['Créditos'] > 0]
graf3 = pd.crosstab(df_credito['Trimestre'], df_credito['categoria'], margins=True, margins_name='Total', normalize=True)
graf3
# Out:
# categoria  Alimentos  Auto posto  Construção  Farmácia   Mercado  \
# Trimestre
# 2017Q1      0.014982    0.000024    0.001264  0.001560  0.002777
# 2017Q2      0.020499    0.000071    0.001441  0.000721  0.002895
# 2017Q3      0.015478    0.000000    0.001548  0.001111  0.004608
# 2017Q4      0.006640    0.000012    0.001713  0.000662  0.002528
# 2018Q1      0.000366    0.000035    0.000744  0.000354  0.002269
# 2018Q2      0.000733    0.000000    0.001205  0.000402  0.005754
# 2018Q3      0.000662    0.000189    0.001276  0.000756  0.003875
# 2018Q4      0.000922    0.000047    0.002056  0.001087  0.012973
# 2019Q1      0.012063    0.000177    0.010964  0.001512  0.007278
# 2019Q2      0.019566    0.000307    0.011756  0.002032  0.008755
# 2019Q3      0.010870    0.000366    0.012465  0.002847  0.012063
# 2019Q4      0.008590    0.000378    0.027860  0.002363  0.012571
# 2020Q1      0.005896    0.000260    0.010752  0.002670  0.017309
# 2020Q2      0.004123    0.000236    0.008696  0.002824  0.016104
# 2020Q3      0.004525    0.000201    0.010492  0.003155  0.019105
# 2020Q4      0.005778    0.000165    0.010799  0.005683  0.020523
# 2021Q1      0.004832    0.000142    0.010645  0.004868  0.021338
# 2021Q2      0.004572    0.000095    0.011154  0.006829  0.020547
# 2021Q3      0.005506    0.000284    0.013186  0.007987  0.020712
# 2021Q4      0.005435    0.000213    0.013162  0.008306  0.020050
# Total       0.152038    0.003202    0.163179  0.057729  0.234035
#
# categoria  Restaurantes    Varejo  Vestuário  não definido     Total
# Trimestre
# 2017Q1         0.039250  0.000024   0.000189      0.002410  0.062479
# 2017Q2         0.027116  0.000047   0.000508      0.003296  0.056595
# 2017Q3         0.023524  0.000024   0.000709      0.003025  0.050025
# 2017Q4         0.022142  0.000035   0.000520      0.002446  0.036698
# 2018Q1         0.000709  0.000047   0.000154      0.000744  0.005423
# 2018Q2         0.001560  0.000106   0.000390      0.001938  0.012087
# 2018Q3         0.004372  0.000106   0.001099      0.002115  0.014450
# 2018Q4         0.004395  0.000118   0.002115      0.001902  0.025615
# 2019Q1         0.007715  0.000378   0.001583      0.007349  0.049021
# 2019Q2         0.008684  0.000709   0.002812      0.010433  0.065054
# 2019Q3         0.012264  0.001052   0.003226      0.016778  0.071931
# 2019Q4         0.031310  0.001300   0.002717      0.022626  0.109716
# 2020Q1         0.005317  0.001111   0.000886      0.009795  0.053995
# 2020Q2         0.001725  0.000792   0.000260      0.007314  0.042074
# 2020Q3         0.002174  0.001063   0.000508      0.011083  0.052306
# 2020Q4         0.002044  0.001311   0.000733      0.011520  0.058556
# 2021Q1         0.001654  0.000922   0.000473      0.009192  0.054066
# 2021Q2         0.001808  0.000957   0.000673      0.008542  0.055177
# 2021Q3         0.002517  0.001111   0.000898      0.010338  0.062538
# 2021Q4         0.001973  0.001016   0.000803      0.011236  0.062195
# Total          0.202252  0.012229   0.021255      0.154082  1.000000

# %%
graf3.sort_values(by='Total', axis=1, ascending=False, inplace=True)
graf3.drop('Total', axis=1).drop('Total').plot.bar(figsize=(10,5), edgecolor='black', stacked=True)
plt.ylabel('Quantidade')
plt.title('Quantidade de notas por categoria e por período', fontsize=14)
plt.legend(bbox_to_anchor=(1, 1))

# %%
df.groupby(['Trimestre', 'categoria'])['Créditos'].mean().unstack()
# Out:
# categoria  Alimentos  Auto posto  Construção   Farmácia    Mercado  \
# Trimestre
# 2017Q1      0.578809    0.000793    0.273099   0.059202   1.204702
# 2017Q2      0.624214    0.004366    1.054773   0.131044   3.802062
# 2017Q3      0.446071    0.000000    1.017959   0.219954   6.110078
# 2017Q4      0.482408    0.000018    1.332277   0.292500   5.664539
# 2018Q1     26.377500    0.282364   26.327431  17.116383  18.367824
# 2018Q2     20.021875    0.000000   23.096615   4.415085  11.651303
# 2018Q3     17.439277    0.375085   16.860990   2.848280  13.910249
# 2018Q4     32.379604    1.789273   29.276478   4.271613   5.925116
# 2019Q1      7.037265    0.746292    9.906520   2.144593  18.737750
# 2019Q2      5.084425    2.637699   13.341452   1.710997  14.287509
# 2019Q3     10.243007    1.341130    7.529006   2.145202  11.594851
# 2019Q4     15.444600    1.580714    9.766019   1.445854  12.601948
# 2020Q1     13.649087    2.309659   16.991621   1.697381  12.365047
# 2020Q2     13.857829    2.580645   15.787473   1.834077  13.315976
# 2020Q3     14.688246    1.762281   17.718253   1.916728  10.463154
# 2020Q4     15.384219    1.839355   18.512656   2.644074  12.134270
# 2021Q1     14.116179    1.025937   14.473677   2.734901   9.365919
# 2021Q2     10.528843    0.235741   14.378354   3.466286   9.228336
# 2021Q3     13.974777    0.773291   16.474284   3.592237   6.630826
# 2021Q4     13.278534    0.605135   15.884508   3.554737   6.773432
#
# categoria  Restaurantes     Varejo  Vestuário  não definido
# Trimestre
# 2017Q1         0.079058   0.144615   4.336111      2.011965
# 2017Q2         0.132338   0.111176   3.172955      2.264436
# 2017Q3         0.100589   0.097222   2.090645      2.047060
# 2017Q4         0.133122  14.876667   3.328913      3.068867
# 2018Q1         1.036810  21.522500   5.792143     15.966480
# 2018Q2         0.153151  11.841154  23.204750     17.710366
# 2018Q3         0.102287  11.290857   1.098020     11.398472
# 2018Q4         0.435930  24.198750   9.407136     22.342343
# 2019Q1         1.268562  10.646176  12.118432     16.126107
# 2019Q2         1.942188  13.713083  10.154172     15.805246
# 2019Q3         0.661543  10.411038  17.049401     12.483446
# 2019Q4         0.541528  12.220168  32.966311     12.479310
# 2020Q1         5.057708   3.486015  25.758340     14.974808
# 2020Q2        20.762256   1.803919  16.849353     11.636345
# 2020Q3        16.360841   1.236585  18.175327     14.468663
# 2020Q4        11.584934   2.151334  30.343506     17.057799
# 2021Q1        10.496150   1.346750  21.430979     12.568206
# 2021Q2        11.281818   1.886020  24.454425     12.911483
# 2021Q3        12.530627   2.028538  36.791322     13.218121
# 2021Q4         8.774708   1.845873  24.747840     13.615526

# %%
df_credito[['categoria', 'Créditos']]
# Out:
#            categoria  Créditos
# 2       Restaurantes      0.44
# 3       Restaurantes      1.81
# 4       Restaurantes      2.03
# 5       Restaurantes      0.38
# 6       Restaurantes      0.91
# ...              ...       ...
# 187631        Varejo      2.95
# 187633     Alimentos      0.61
# 187635       Mercado      1.88
# 187636  Restaurantes     10.80
# 187637       Mercado      0.56
#
# [84637 rows x 2 columns]

# %% [markdown]
# ## Avalie o WOE e o IV no tempo
#
# Avalie o WOE e o IV no tempo da variável ```categoria```.

# %% [markdown]
# ## Conclua
#
# - Quais categorias parece ter maior proporção de notas com retornos maiores que zero?
# - Essas diferenças são estáveis no tempo?
#
# Dicas:<br>
# - Considere que a quantidade de notas vem aumentando
# - Considere que há períodos bem atípicos no histórico
# - Considere que a partir de janeiro de 2020 o público é mais parecido com o público atual (2022), seja por pandemia, seja por crescimento do público, e considere os dados dessa data em diante na sua conclusão.
