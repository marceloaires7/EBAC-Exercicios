# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import statsmodels.formula.api as smf

from formulas import analise
from formulas import stats

sns.set_theme()

# %reload_ext watermark
# %watermark -iv -v
# Out:
# Python implementation: CPython
# Python version       : 3.12.1
# IPython version      : 8.21.0
#
# seaborn    : 0.13.2
# statsmodels: 0.14.1
# matplotlib : 3.8.3
# streamlit  : 1.31.1
# pandas     : 2.2.0

# %%
df = pd.read_csv('./Dados/matches.csv', index_col=0, parse_dates=['Date']).drop(columns='Notes')
df['Result'].replace({'D': 0, 'L': 0, 'W': 1}, inplace=True)
df
# Out:
# C:\Users\Marcelo\AppData\Local\Temp\ipykernel_6792\1547471011.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Result'].replace({'D': 0, 'L': 0, 'W': 1}, inplace=True)
# C:\Users\Marcelo\AppData\Local\Temp\ipykernel_6792\1547471011.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Result'].replace({'D': 0, 'L': 0, 'W': 1}, inplace=True)
#          Date   Time            Comp         Round  Day Venue  Result   GF  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away       0  1.0
# 1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home       1  3.0
# 2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away       1  2.0
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home       1  3.0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away       1  3.0
# ..        ...    ...             ...           ...  ...   ...     ...  ...
# 20 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Away       0  0.0
# 22 2024-01-21  14:00  Premier League  Matchweek 21  Sun  Home       0  2.0
# 24 2024-01-30  20:00  Premier League  Matchweek 22  Tue  Away       0  2.0
# 25 2024-02-03  17:30  Premier League  Matchweek 23  Sat  Home       0  0.0
# 26 2024-02-10  15:00  Premier League  Matchweek 24  Sat  Away       1  3.0
#
#      GA         Opponent  ...            Referee  Match Report    Sh  SoT  \
# 0   1.0          Chelsea  ...     Anthony Taylor  Match Report  13.0  1.0
# 1   1.0      Bournemouth  ...     Thomas Bramall  Match Report  25.0  9.0
# 2   1.0    Newcastle Utd  ...        John Brooks  Match Report   9.0  4.0
# 3   0.0      Aston Villa  ...       Simon Hooper  Match Report  17.0  4.0
# 4   1.0           Wolves  ...     Michael Oliver  Match Report  16.0  5.0
# ..  ...              ...  ...                ...           ...   ...  ...
# 20  2.0  Manchester City  ...        David Coote  Match Report   4.0  2.0
# 22  2.0         West Ham  ...  Michael Salisbury  Match Report  20.0  5.0
# 24  3.0   Crystal Palace  ...    Tony Harrington  Match Report   9.0  5.0
# 25  5.0      Aston Villa  ...       Paul Tierney  Match Report  10.0  4.0
# 26  1.0       Luton Town  ...     Chris Kavanagh  Match Report   6.0  2.0
#
#     Dist   FK PK PKatt  Season             Team
# 0   17.8  0.0  0     0    2024        Liverpool
# 1   16.8  1.0  0     1    2024        Liverpool
# 2   17.2  1.0  0     0    2024        Liverpool
# 3   14.7  0.0  0     0    2024        Liverpool
# 4   15.8  0.0  0     0    2024        Liverpool
# ..   ...  ... ..   ...     ...              ...
# 20  14.9  0.0  0     0    2024  SheffieldUnited
# 22  18.5  1.0  1     1    2024  SheffieldUnited
# 24  16.5  0.0  0     0    2024  SheffieldUnited
# 25  10.0  0.0  0     0    2024  SheffieldUnited
# 26  22.4  0.0  1     1    2024  SheffieldUnited
#
# [476 rows x 26 columns]

# %%
res_1 = smf.ols('''Result ~ Venue
                          + Opponent
                          + xG
                          + xGA
                          + Poss
                          + Formation
                          + Sh
                          + SoT
                          + Dist
                          + Team''', data= df).fit()

res_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Result   R-squared:                       0.481
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     6.402
# Date:                Thu, 22 Feb 2024   Prob (F-statistic):           8.15e-32
# Time:                        21:31:57   Log-Likelihood:                -179.64
# No. Observations:                 476   AIC:                             481.3
# Df Residuals:                     415   BIC:                             735.4
# Df Model:                          60
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.5521      0.299      1.845      0.066      -0.036       1.140
# Venue[T.Home]                      0.0958      0.038      2.532      0.012       0.021       0.170
# Opponent[T.Aston Villa]            0.0137      0.115      0.119      0.905      -0.213       0.240
# Opponent[T.Bournemouth]            0.2390      0.120      1.984      0.048       0.002       0.476
# Opponent[T.Brentford]              0.3574      0.118      3.021      0.003       0.125       0.590
# Opponent[T.Brighton]              -0.0788      0.115     -0.685      0.494      -0.305       0.147
# Opponent[T.Burnley]                0.3548      0.121      2.925      0.004       0.116       0.593
# Opponent[T.Chelsea]                0.0657      0.114      0.575      0.565      -0.159       0.290
# Opponent[T.Crystal Palace]         0.3400      0.122      2.797      0.005       0.101       0.579
# Opponent[T.Everton]                0.4017      0.121      3.307      0.001       0.163       0.640
# Opponent[T.Fulham]                 0.1362      0.118      1.153      0.249      -0.096       0.368
# Opponent[T.Liverpool]             -0.1390      0.113     -1.234      0.218      -0.361       0.083
# Opponent[T.Luton Town]             0.3756      0.125      3.010      0.003       0.130       0.621
# Opponent[T.Manchester City]       -0.1813      0.117     -1.554      0.121      -0.411       0.048
# Opponent[T.Manchester Utd]         0.1172      0.116      1.010      0.313      -0.111       0.345
# Opponent[T.Newcastle Utd]          0.1363      0.115      1.189      0.235      -0.089       0.362
# Opponent[T.Nott'ham Forest]        0.3744      0.122      3.068      0.002       0.135       0.614
# Opponent[T.Sheffield Utd]          0.4551      0.128      3.544      0.000       0.203       0.708
# Opponent[T.Tottenham]             -0.1096      0.116     -0.944      0.346      -0.338       0.119
# Opponent[T.West Ham]               0.1855      0.123      1.512      0.131      -0.056       0.427
# Opponent[T.Wolves]                 0.1101      0.119      0.922      0.357      -0.125       0.345
# Formation[T.3-4-1-2]               1.1059      0.453      2.444      0.015       0.216       1.995
# Formation[T.3-4-3]                 0.3963      0.212      1.870      0.062      -0.020       0.813
# Formation[T.3-5-2]                 0.4118      0.224      1.839      0.067      -0.028       0.852
# Formation[T.4-1-2-1-2◆]            0.3078      0.339      0.908      0.364      -0.359       0.974
# Formation[T.4-1-4-1]               0.3992      0.224      1.779      0.076      -0.042       0.840
