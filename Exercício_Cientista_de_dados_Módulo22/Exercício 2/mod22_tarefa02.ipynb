# %% [markdown]
# # Tarefa 02
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Carregue os dados da tarefa anterior

# %%
# Importação dos Pacotes.

from pandas_datareader import data as web
import yfinance as yfin

import plotly.express as px
from plotly import graph_objects

import pandas as pd
import numpy as np

# Versões dos Pacotes.

# %reload_ext watermark
# %watermark --iversions --python
# Out:
# Python implementation: CPython
# Python version       : 3.11.6
# IPython version      : 8.16.0
#
# numpy            : 1.26.0
# yfinance         : 0.2.31
# pandas_datareader: 0.10.0
# plotly           : 5.17.0
# pandas           : 2.1.1

# %%
# Coletando Dados das Ações desejadas através do Yahoo Finance.

yfin.pdr_override()

ativos = ['TSLA', 'AAPL', 'AMZN']
dt_ini = '2021-01-01'

df = web.get_data_yahoo(ativos, dt_ini)

df.head()
# Out:
# [*********************100%%**********************]  3 of 3 completed
#              Adj Close                               Close              \
#                   AAPL        AMZN        TSLA        AAPL        AMZN
# Date
# 2021-01-04  127.331680  159.331497  243.256668  129.410004  159.331497
# 2021-01-05  128.905975  160.925507  245.036667  131.009995  160.925507
# 2021-01-06  124.566818  156.919006  251.993332  126.599998  156.919006
# 2021-01-07  128.817429  158.108002  272.013336  130.919998  158.108002
# 2021-01-08  129.929306  159.134995  293.339996  132.050003  159.134995
#
#                               High                                 Low  \
#                   TSLA        AAPL        AMZN        TSLA        AAPL
# Date
# 2021-01-04  243.256668  133.610001  163.600006  248.163330  126.760002
# 2021-01-05  245.036667  131.740005  161.169006  246.946671  128.429993
# 2021-01-06  251.993332  131.050003  159.875504  258.000000  126.379997
# 2021-01-07  272.013336  131.630005  160.427002  272.329987  127.860001
# 2021-01-08  293.339996  132.630005  159.531998  294.829987  130.229996
#
#                                           Open                          \
#                   AMZN        TSLA        AAPL        AMZN        TSLA
# Date
# 2021-01-04  157.201004  239.063339  133.520004  163.500000  239.820007
# 2021-01-05  158.253006  239.733337  128.889999  158.300507  241.220001
# 2021-01-06  156.557999  249.699997  127.720001  157.324005  252.830002
# 2021-01-07  157.750000  258.399994  128.360001  157.850006  259.209991
# 2021-01-08  157.110001  279.463318  132.429993  159.000000  285.333344
#
#                Volume
#                  AAPL      AMZN       TSLA
# Date
# 2021-01-04  143301900  88228000  145914600
# 2021-01-05   97664900  53110000   96735600
# 2021-01-06  155088000  87896000  134100000
# 2021-01-07  109578200  70290000  154496700
# 2021-01-08  105158200  70754000  225166500

# %% [markdown]
# #### 2. Média móvel
#
# 1. Faça uma média móvel  em 90 dias dos valores de fechamento ajustados dos ativos que você escolheu
# 2. Utilizando a fução ```rolling()```, calcule o desvio pardão desses ativos ao longo do tempo, utilizando a mesma janela móvel do item acima
# 2. Monte um gráfico de linhas para as médias móveis dos ativos da sua base
# 4. Monte um gráfico de linhas para os desvios padrão em janela móvel
# 5. Compare os dois gráficos que você fez com o da tarefa anterior. Veja se eles apontam conclusões semelhantes quanto aos períodos de maior volatilidade (variação) dos ativos.

# %%
Ex2 = df['Adj Close'].rolling(90).mean().stack().reset_index()
Ex2.columns = ['Data', 'Ativo', 'MediaMovel']

Ex2['Adj Close'] = (df['Adj Close'].stack()
                    [df['Adj Close'].stack().shape[0]-Ex2.shape[0]:]
                    .reset_index()[0])

Ex2['DesvioPadrao'] = df['Adj Close'].rolling(90).std().stack().reset_index()[0]

Ex2
# Out:
#            Data Ativo  MediaMovel   Adj Close  DesvioPadrao
# 0    2021-05-12  AAPL  127.207303  121.184326      5.890551
# 1    2021-05-12  AMZN  161.063094  157.597000      6.313722
# 2    2021-05-12  TSLA  244.621481  196.630005     27.614613
# 3    2021-05-13  AAPL  127.163127  123.355911      5.904499
# 4    2021-05-13  AMZN  161.049117  158.073502      6.318989
# ...         ...   ...         ...         ...           ...
# 1831 2023-10-13  AMZN  132.039556  129.789993      5.246661
# 1832 2023-10-13  TSLA  256.297333  251.119995     15.566029
# 1833 2023-10-16  AAPL  182.911016  178.720001      7.210893
# 1834 2023-10-16  AMZN  132.165334  132.550003      5.118740
# 1835 2023-10-16  TSLA  256.623444  253.919998     15.196936
#
# [1836 rows x 5 columns]

# %%
# Criando Gráfico para analisar a MediaMovel ao longo do tempo.

fig = px.line(Ex2, x="Data", y="MediaMovel", color='Ativo', template='plotly_white')
fig.show()
# Out:
# C:\Users\marce\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\_plotly_utils\basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
# Criando Gráfico para analisar a DesvioPadrao ao longo do tempo.

fig = px.line(Ex2, x="Data", y="DesvioPadrao", color='Ativo', template='plotly_white')
fig.show()
# Out:
# C:\Users\marce\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\_plotly_utils\basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %% [markdown]
# #### 3. Gráfico de *candlestick*
# 1. Selecione o período dos últimos 60 dias (corridos) para um dos ativos da sua base
# 2. Monte um gráfico de *candlestick* para esses dados.
